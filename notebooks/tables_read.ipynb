# %%
import duckdb, os
if os.path.exists("../data/lol.duckdb"): os.remove("../data/lol.duckdb")
con = duckdb.connect("../data/lol.duckdb")
con.execute(open("../src/db/schema.sql").read())
con.sql("SHOW TABLES")
